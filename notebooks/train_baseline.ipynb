# %% [markdown]
# # Baseline: TF-IDF + Logistic Regression
#
# Ноутбук повторяет CLI-команды обучения baseline-модели.

# %%
# !PYTHONPATH=../src python -m math_solution_analyzer.dataset --n 800 --output ../data/processed/step_classification.csv

# %%
# !PYTHONPATH=../src python -m math_solution_analyzer.models.train --dataset ../data/processed/step_classification.csv --model ../models/tfidf_logreg.joblib --metrics ../reports/metrics.json
