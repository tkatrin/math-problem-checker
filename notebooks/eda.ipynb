# %% [markdown]
# # EDA для датасета шагов
#
# Минимальный ноутбук-заготовка: распределение меток, типов ошибок и доменов.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/step_classification.csv')
df.head()

# %%
df['label'].value_counts(normalize=True), df['error_type'].value_counts().head(10)
